# %% [raw]
# ---
# #title: "Making AI Safe Where Failure Isn’t an Option"
# #subtitle: "Human-centered AI for performance and safety in critical industries."
# #about:
#   #template: jolla
#   #image: images/profile2.jpg
#   #image-width: 7em
#   #image-shape: round
#   #links:
#     #- text: Services
#       #href: services.qmd
#       #icon: boxes
#     #- text: Projects
#       #href: projects.qmd
#       #icon: boxes
#     #- text: About Me
#       #href: about.qmd
#       #icon: boxes
# ---

# %% [markdown]
# ```{html}
# <!-- Sticky Navigation -->
#
# <nav class="navbar">
#
# ::: nav-container
# ```
#
# <a href="#about">About</a>
# <a href="#services">Services</a>
# <a href="#industries">Industries</a>
# <a href="#experience">Experience</a>
# <a href="#contact">Contact</a>
# ```
# :::
#
# </nav>
# ```
#
# ------------------------------------------------------------------------
#
# <!-- Hero Section -->
#
# ::: {.hero style="text-align: center;"}
# <h1 style="font-size: 2.5rem; font-weight: 700; margin-bottom: 1rem;">
#
# Making AI Safe Where Failure Isn't an Option
#
# </h1>
#
# <p style="max-width: 700px; margin: 0 auto 2rem; font-size: 1.2rem; font-weight: 300;">
#
# We help high-risk industries integrate AI systems safely, compliantly, and effectively.\
# Our expertise bridges <strong>human factors</strong> and <strong>AI evaluation</strong>\
# in nuclear, aerospace, energy, defense, and other safety-critical sectors.
#
# </p>
#
# <a href="capability.pdf" class="btn btn-primary btn-lg"> View Capability Statement </a>
# :::
#
# ------------------------------------------------------------------------
#
# ## About {#about}
#
# Cognisafe Consulting specializes in evaluating and optimizing human--AI interaction in safety-critical environments.\
# Led by \[Your Name\], PhD, we combine human factors expertise with deep knowledge of AI system evaluation, ensuring new technologies meet strict regulatory, usability, and ethical requirements.
#
# **Our Mission:**\
# To make advanced technology safe, intuitive, and compliant---especially when lives, infrastructure, and reputations are on the line.
#
# ------------------------------------------------------------------------
#
# ## Services {#services}
#
# ::: {.grid .grid-2}
# ### Human--AI Interaction Audits
#
# Identify and address risks in AI-assisted decision-making environments.
#
# ### Compliance & Regulatory Support
#
# Navigate EU AI Act, IEC, ISO, and sector-specific safety requirements.
#
# ### Usability & Workload Testing
#
# Ensure operators can perform effectively and safely with AI tools.
#
# ### Training & Advisory
#
# Equip engineers, operators, and regulators with human--AI safety best practices.
# :::
#
# ------------------------------------------------------------------------
#
# ## Industries {#industries}
#
# Nuclear Energy • Aerospace • Defense • Rail & Transport • Medical Devices • Industrial Automation
#
# ------------------------------------------------------------------------
#
# ## Experience {#experience}
#
# > **Nuclear Control Room Optimization** -- Reduced predicted critical error risk by **25%** through targeted human--AI interaction redesign.
#
# > **AI Compliance Testing** -- Developed testing framework for AI-assisted diagnostics aligned with draft EU AI Act standards.
#
# > **Aerospace Safety Training** -- Delivered human--AI integration training to engineering teams in aerospace and energy sectors.
#
# ------------------------------------------------------------------------
#
# ## Contact {#contact}
#
# **Let's Talk**\
# Whether you're integrating AI into a control room, cockpit, or command center, we can help you make it safe, usable, and compliant.
#
# **Email:** [you\@example.com](mailto:you@example.com)\
# **Phone:** +1 (XXX) XXX-XXXX\
# **LinkedIn:** [linkedin.com/in/yourprofile](https://linkedin.com/in/yourprofile)
#
# <form action="https://formspree.io/f/yourformid" method="POST">
#
# <input type="text" name="name" placeholder="Your Name" required><br> <input type="email" name="_replyto" placeholder="Your Email" required><br>
#
#
# ```{=html}
# <textarea name="message" placeholder="Your Message" required></textarea>
# ```
#
# <br> <button type="submit">Send</button>
#
# </form>
#
# ------------------------------------------------------------------------
#
# <footer style="text-align:center; font-size: 0.85em; padding: 1rem 0;">
#
# Cognisafe Consulting © 2025 --- Human--AI Safety in Safety-Critical Systems
#
# </footer>
